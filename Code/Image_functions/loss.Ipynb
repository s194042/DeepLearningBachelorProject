# %%
import torch
from torch import nn
import numpy as np
from torchsummary import summary
import loss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

summary(loss.Loss(loss.Down_block).to(device), (6, 768, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 768, 512]             324
#             Conv2d-2          [-1, 6, 768, 512]             900
#             Conv2d-3          [-1, 6, 768, 512]              36
#                ELU-4         [-1, 18, 768, 512]               0
#             Conv2d-5         [-1, 12, 768, 512]             216
#                ELU-6         [-1, 12, 768, 512]               0
#          AvgPool2d-7         [-1, 12, 383, 255]               0
#         Down_block-8         [-1, 12, 383, 255]               0
#             Conv2d-9         [-1, 12, 383, 255]           1,296
#            Conv2d-10         [-1, 12, 383, 255]           3,600
#            Conv2d-11         [-1, 12, 383, 255]             144
#               ELU-12         [-1, 36, 383, 255]               0
#            Conv2d-13         [-1, 24, 383, 255]             864
# ...

# %%
summary(loss.Loss(loss.Down_with_slim_kernels).to(device), (6, 768, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 768, 512]             108
#             Conv2d-2          [-1, 6, 768, 512]             108
#             Conv2d-3          [-1, 6, 768, 512]             180
#             Conv2d-4          [-1, 6, 768, 512]             180
#             Conv2d-5          [-1, 6, 768, 512]              36
#                ELU-6         [-1, 18, 768, 512]               0
#             Conv2d-7         [-1, 12, 768, 512]             216
#                ELU-8         [-1, 12, 768, 512]               0
#          AvgPool2d-9         [-1, 12, 383, 255]               0
# Down_with_slim_kernels-10         [-1, 12, 383, 255]               0
#            Conv2d-11         [-1, 12, 383, 255]             432
#            Conv2d-12         [-1, 12, 383, 255]             432
#            Conv2d-13         [-1, 12, 383, 255]             720
# ...

# %%
summary(loss.Loss(loss.Down_with_depthwise_Seperable).to(device), (6, 768, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 768, 512]              36
#             Conv2d-2          [-1, 6, 768, 512]              54
#             Conv2d-3          [-1, 6, 768, 512]              36
#             Conv2d-4          [-1, 6, 768, 512]             150
#             Conv2d-5          [-1, 6, 768, 512]              36
#             Conv2d-6          [-1, 6, 768, 512]              36
#                ELU-7         [-1, 18, 768, 512]               0
#             Conv2d-8         [-1, 12, 768, 512]             216
#                ELU-9         [-1, 12, 768, 512]               0
#         AvgPool2d-10         [-1, 12, 383, 255]               0
# Down_with_depthwise_Seperable-11         [-1, 12, 383, 255]               0
#            Conv2d-12         [-1, 12, 383, 255]             144
# ...

# %%
summary(loss.Loss(loss.Down_final).to(device), (6, 768, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 768, 512]              36
#             Conv2d-2          [-1, 6, 768, 512]              18
#             Conv2d-3          [-1, 6, 768, 512]              18
#             Conv2d-4          [-1, 6, 768, 512]              36
#             Conv2d-5          [-1, 6, 768, 512]              30
#             Conv2d-6          [-1, 6, 768, 512]              30
#             Conv2d-7          [-1, 6, 768, 512]              36
#                ELU-8         [-1, 18, 768, 512]               0
#             Conv2d-9         [-1, 12, 768, 512]             216
#               ELU-10         [-1, 12, 768, 512]               0
#         AvgPool2d-11         [-1, 12, 383, 255]               0
#        Down_final-12         [-1, 12, 383, 255]               0
#            Conv2d-13         [-1, 12, 383, 255]             144
# ...

# %%
import torch
from torch import nn
import numpy as np
from torchsummary import summary
import loss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
summary(loss.Loss().to(device), (6, 768, 512))
# Out:
# c:\Users\Rani\Documents\GitHub\DeepLearningBachelorProject\Code\Image_functions\loss.py:402: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(m.weight)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 768, 512]             324
#                ELU-2          [-1, 6, 768, 512]               0
#             Conv2d-3          [-1, 6, 768, 512]             324
#                ELU-4          [-1, 6, 768, 512]               0
#              Same3-5          [-1, 6, 768, 512]               0
#             Conv2d-6         [-1, 12, 768, 512]             648
#                ELU-7         [-1, 12, 768, 512]               0
#          MaxPool2d-8         [-1, 12, 384, 256]               0
#                ELU-9         [-1, 12, 384, 256]               0
# ...

# %%
import torch
from torch import nn
import numpy as np
from torchsummary import summary
import loss
torch.manual_seed(10)
np.random.seed(10)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import generateLossImages
training = generateLossImages.MakeIter(generateLossImages.get_image_pairs_transforms_with_loss(cupy=True)) 

val = generateLossImages.get_image_pairs_transforms_with_loss("C:/Users/Rani/Desktop/ai_val/16")

training_loader = torch.utils.data.DataLoader(training)


model = loss.Loss().to(device)

loss_fn = torch.nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0002)

epoch_index = 1
running_loss = 0.
last_loss = 0.
#num = 0
lis = []
flag = True
flag2 = True
flag3 = True
for i, data in enumerate(training_loader):

    inputs, labels = data


    labels = labels.to("cuda")
    

    # Make predictions for this batch
    outputs = model(inputs)

    # Compute the loss and its gradients
    loss = loss_fn(outputs, labels)
    loss.backward()

    

    # Gather data and report
    running_loss += loss.item()
    lis.append((f'{outputs.item():.3}',f'{labels.item():.3}'))
    if i % 71 == 70:
        #num += 1
        # Zero your gradients for every batch!
        
        optimizer.step()
        optimizer.zero_grad()
        # Adjust learning weights
        last_loss = running_loss / 71 # loss per batch
        print('  batch {} loss: {}'.format(i + 1, last_loss))
        print(lis)
        lis = []
        tb_x = epoch_index * len(training_loader) + i + 1
        running_loss = 0

        if flag and last_loss < 0.13:
            flag = False
            for g in optimizer.param_groups:
                g['lr'] = 0.00005
        if flag2 and last_loss < 0.08:
            flag2 = False
            for g in optimizer.param_groups:
                g['lr'] = 0.00001
        if flag3 and last_loss < 0.06:
            flag3 = False
            for g in optimizer.param_groups:
                g['lr'] = 0.000003
        #if num == 140:
        #    for g in optimizer.param_groups:
        #        g['lr'] = g['lr'] / 2.1
        #    print("down", g['lr'])
        #    num = 0
# Out:
# c:\Users\Rani\anaconda3\envs\torch\lib\site-packages\torch\nn\modules\loss.py:101: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
#   batch 71 loss: 0.28057127393467324
# ...
