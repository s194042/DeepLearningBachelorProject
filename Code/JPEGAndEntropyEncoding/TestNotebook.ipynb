# %%
from JPEGAndEntropyEncoding import *
from random import randint
import numpy as np
from PIL import Image

# %%
imarray = np.array(Image.open("TestImages/kodim06.png"))

# %%
result_array = np.array(JPEGcompress_and_decompress(imarray,100,"Down444"),dtype=np.uint8)
Image.fromarray(result_array)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
JPEG_compress_to_file(imarray,50,"Down444","testcompression")

# %%
JPEG_compress_to_file(imarray,50,"Down444","testcompression")
result_array = np.array(JPEG_decompress_from_file("testcompression"),dtype=np.uint8)
Image.fromarray(result_array)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
Image.fromarray(imarray)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>
