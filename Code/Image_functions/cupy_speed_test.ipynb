# %%
import augmentations
import matplotlib.pyplot as plt
import images
import torchvision.transforms.functional as F
import torchvision.transforms as T
import numpy as np
import torch

img = list(images.get_compressed_imgs(images.load_nef()))[-1]
im = torch.clone(img)
im = im.detach().cpu().numpy()
im = np.rint(im)
im = im.astype(np.uint8)
plt.imshow(im)
print(im.max())
img = img.permute(2,0,1)
# Out:
# 255

# %%
# read input image as torch tensor
# adjust sharpness
for _ in range(10000):
    img = F.adjust_sharpness(img, 5.0)

# %%
for _ in range(10000):
    img = augmentations.sharpen(img)

# %%
for i in range(10):
    bla = augmentations.box_blur_5x5(img, cupy=False)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.box_blur_5x5(img, cupy=True)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.salt(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.salt(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.peper(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.peper(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Guasian_noice(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Guasian_noice(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Poiss_noice(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Poiss_noice(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Exp_noice(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(10):
    bla = augmentations.Exp_noice(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.Uniform_noice(img, 0.1, cupy=False)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.Uniform_noice(img, 0.1, cupy=True)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.uniform_add(img, 20, cupy=False)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.uniform_add(img, 20, cupy=True)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.uniform_decimal_multiplication(img, 20, cupy=False)
#plt.imshow(bla)

# %%
for i in range(100):
    bla = augmentations.uniform_decimal_multiplication(img, 20, cupy=True)
#plt.imshow(bla)

# %%
import generateLossImages
import torch
import numpy as np
def get_image_pairs_transforms_with_loss(path='C:/Users/Rani/Desktop/ai_training_immages/_0', cupy=False):
    imgs = images.get_all_imgs_with_everything(path)
    for img in imgs:
        for aug_0 in generateLossImages.get_images_with_loss_of_0(img, cupy):
            yield aug_0
        for aug_0 in generateLossImages.get_images_with_loss_of_1(img, cupy):
            yield aug_0
        for aug_0 in generateLossImages.get_images_with_loss_of_0_2(img, cupy):
            yield aug_0
        for aug_0 in generateLossImages.get_images_with_loss_of_0_6(img, cupy):
            yield aug_0
        for aug_0 in generateLossImages.get_images_with_loss_of_0_4(img, cupy):
            yield aug_0
        for aug_0 in generateLossImages.get_images_with_loss_of_0_8(img, cupy):
            yield aug_0
        break

# %%
for _ in range(10):
    a = list(get_image_pairs_transforms_with_loss(cupy= False))

# %%
for _ in range(10):
    a = list(get_image_pairs_transforms_with_loss(cupy= True))
