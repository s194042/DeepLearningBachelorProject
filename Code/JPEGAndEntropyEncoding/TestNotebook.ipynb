# %%
from JPEGAndEntropyEncoding import *
from random import randint
import numpy as np
from PIL import Image

# %%
im = Image.open("TestImages/kodim06.png")

# %%
imarray = np.array(im)
imarray.shape
# Out:
# (512, 768, 3)

# %%
test_res = JPEGcompress_and_decompress(imarray,50)
result_array = np.array(test_res,dtype=np.uint8)
result_array.shape
Image.fromarray(result_array)
# Out:
# (512, 768, 3)

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
result_array.shape
# Out:
# (512, 768, 3)

# %%
Image.fromarray(imarray)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>
